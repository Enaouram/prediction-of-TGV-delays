# %% [markdown]
# # Fusionner les datasets pour ajouter des features

# %%
import pandas as pd
import os

# Charger le dataset des jours fériés
script_dir = os.path.abspath('')
relative_path = 'nb_jours_ferie.csv'
csv_path = os.path.join(script_dir, relative_path)
data_jours_ferie = pd.read_csv(csv_path, delimiter=",")

data_jours_ferie.head()
# Out:
#    annee  mois  nombre_jour_ferie
# 0   2003     1                  1
# 1   2003     4                  1
# 2   2003     5                  3
# 3   2003     6                  1
# 4   2003     7                  1

# %%
# Charger le dataset des retards de trains
relative_path = 'regularite-mensuelle-tgv-aqst.csv'
csv_path = os.path.join(script_dir, relative_path)
data_retards = pd.read_csv(csv_path, delimiter=";")

data_jours_ferie['annee'] = data_jours_ferie['date'].dt.year
data_jours_ferie['mois'] = data_jours_ferie['date'].dt.month

data_retards.head()
# Out:
#       date   service         gare_depart         gare_arrivee  duree_moyenne  \
# 0  2018-01  National    BORDEAUX ST JEAN   PARIS MONTPARNASSE            141
# 1  2018-01  National   LA ROCHELLE VILLE   PARIS MONTPARNASSE            165
# 2  2018-01  National  PARIS MONTPARNASSE              QUIMPER            220
# 3  2018-01  National  PARIS MONTPARNASSE              ST MALO            156
# 4  2018-01  National  PARIS MONTPARNASSE  ST PIERRE DES CORPS             61
#
#    nb_train_prevu  nb_annulation  commentaire_annulation  \
# 0             870              5                     NaN
# 1             222              0                     NaN
# 2             248              1                     NaN
# 3             102              0                     NaN
# 4             391              2                     NaN
#
#    nb_train_depart_retard  retard_moyen_depart  ...  nb_train_retard_sup_15  \
# 0                     289            11.247809  ...                     110
# ...

# %%
# Fusionner les deux datasets en utilisant la colonne 'date' comme clé de fusion
merged_data = pd.merge(data_retards, data_jours_ferie, left_on=['annee', 'mois'], right_on=['annee', 'mois'], how='left')

# Le résultat sera un nouveau dataset avec toutes les colonnes des deux datasets
merged_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Romain\Documents\Ecole\Centrale\ML\prediction-of-TGV-delays\dataset\merge_datasets.ipynb Cell 4 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Romain/Documents/Ecole/Centrale/ML/prediction-of-TGV-delays/dataset/merge_datasets.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> # Fusionner les deux datasets en utilisant la colonne 'date' comme clé de fusion
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Romain/Documents/Ecole/Centrale/ML/prediction-of-TGV-delays/dataset/merge_datasets.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> merged_data = pd.merge(data_retards, data_jours_ferie, left_on=['annee', 'mois'], right_on=['annee', 'mois'], how='left')
# ...

# %%
# Pour enregistrer le résultat dans un nouveau fichier CSV
merged_data.to_csv('nouveau_dataset_fusionne.csv', index=False)
